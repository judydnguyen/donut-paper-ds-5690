# %%
# !pip install donut-python
# Out:
# Requirement already satisfied: donut-python in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (1.0.9)
# Requirement already satisfied: transformers>=4.11.3 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (4.25.1)
# Requirement already satisfied: timm in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (0.5.4)
# Requirement already satisfied: datasets[vision] in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (3.0.1)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (1.6.4)
# Requirement already satisfied: nltk in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (3.9.1)
# Requirement already satisfied: sentencepiece in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (0.2.0)
# Requirement already satisfied: zss in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (1.2.0)
# Requirement already satisfied: sconf>=0.2.3 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python) (0.2.5)
# Requirement already satisfied: numpy>=1.17.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.26.4)
# Requirement already satisfied: torch>=1.8.* in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.0.1)
# Requirement already satisfied: tqdm>=4.57.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (6.0.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2023.9.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.13.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.5.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.3.2)
# Requirement already satisfied: packaging>=17.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.12.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python) (3.20.1)
# Requirement already satisfied: ruamel.yaml in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from sconf>=0.2.3->donut-python) (0.18.6)
# Requirement already satisfied: munch in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from sconf>=0.2.3->donut-python) (4.0.0)
# Requirement already satisfied: filelock in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python) (0.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python) (2023.8.8)
# Requirement already satisfied: requests in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python) (0.13.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (0.3.8)
# Requirement already satisfied: pandas in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (2.1.1)
# Requirement already satisfied: xxhash in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (3.5.0)
# Requirement already satisfied: multiprocess in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (0.70.16)
# Requirement already satisfied: aiohttp in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (3.10.10)
# Requirement already satisfied: Pillow>=9.4.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python) (10.4.0)
# Requirement already satisfied: click in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from nltk->donut-python) (8.1.7)
# Requirement already satisfied: joblib in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from nltk->donut-python) (1.3.2)
# Requirement already satisfied: torchvision in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from timm->donut-python) (0.15.2)
# Requirement already satisfied: six in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from zss->donut-python) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python) (1.15.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python) (2024.7.4)
# Requirement already satisfied: absl-py>=0.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.58.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.38.4)
# Requirement already satisfied: sympy in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (1.11.1)
# Requirement already satisfied: networkx in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (3.1)
# Requirement already satisfied: jinja2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (3.1.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torchmetrics>=0.4.1->pytorch-lightning>=1.6.4->donut-python) (0.11.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pandas->datasets[vision]->donut-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pandas->datasets[vision]->donut-python) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pandas->datasets[vision]->donut-python) (2023.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from ruamel.yaml->sconf>=0.2.3->donut-python) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.1.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets[vision]->donut-python) (0.2.0)
# Requirement already satisfied: mpmath>=0.19 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from sympy->torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.2.2)
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !git clone https://github.com/clovaai/donut.git
# %cd donut/
# %conda create -n donut_official python=3.7
# %conda activate donut_official
# %pip install .
# Out:
# Cloning into 'donut'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 62.76 MiB | 32.25 MiB/s, done.
# Resolving deltas: 100% (135/135), done.
# /home/judy/code/donut-paper-cs-5690/donut
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/judy/miniconda3/envs/donut_official
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.16              |       h7a1cb2a_0        44.8 MB
#     setuptools-65.6.3          |   py37h06a4308_0         1.1 MB
#     wheel-0.38.4               |   py37h06a4308_0          63 KB
#     ------------------------------------------------------------
#                                            Total:        52.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.9.24-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py37h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1w-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-22.3.1-py37h06a4308_0
#   python             pkgs/main/linux-64::python-3.7.16-h7a1cb2a_0
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.38.4-py37h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
#
# Note: you may need to restart the kernel to use updated packages.
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# Processing /home/judy/code/donut-paper-cs-5690/donut
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.11.3 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (4.25.1)
# Requirement already satisfied: timm in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (0.5.4)
# Requirement already satisfied: datasets[vision] in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (3.0.1)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (1.6.4)
# Requirement already satisfied: nltk in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (3.9.1)
# Requirement already satisfied: sentencepiece in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (0.2.0)
# Requirement already satisfied: zss in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (1.2.0)
# Requirement already satisfied: sconf>=0.2.3 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from donut-python==1.0.9) (0.2.5)
# Requirement already satisfied: numpy>=1.17.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.26.4)
# Requirement already satisfied: torch>=1.8.* in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (2.0.1)
# Requirement already satisfied: tqdm>=4.57.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (6.0.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (2023.9.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (2.13.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.5.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (0.3.2)
# Requirement already satisfied: packaging>=17.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (4.12.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pytorch-lightning>=1.6.4->donut-python==1.0.9) (3.20.1)
# Requirement already satisfied: ruamel.yaml in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from sconf>=0.2.3->donut-python==1.0.9) (0.18.6)
# Requirement already satisfied: munch in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from sconf>=0.2.3->donut-python==1.0.9) (4.0.0)
# Requirement already satisfied: filelock in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python==1.0.9) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python==1.0.9) (0.26.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python==1.0.9) (2023.8.8)
# Requirement already satisfied: requests in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python==1.0.9) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from transformers>=4.11.3->donut-python==1.0.9) (0.13.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (0.3.8)
# Requirement already satisfied: pandas in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (2.1.1)
# Requirement already satisfied: xxhash in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (3.5.0)
# Requirement already satisfied: multiprocess in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (0.70.16)
# Requirement already satisfied: aiohttp in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (3.10.10)
# Requirement already satisfied: Pillow>=9.4.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from datasets[vision]->donut-python==1.0.9) (10.4.0)
# Requirement already satisfied: click in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from nltk->donut-python==1.0.9) (8.1.7)
# Requirement already satisfied: joblib in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from nltk->donut-python==1.0.9) (1.3.2)
# Requirement already satisfied: torchvision in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from timm->donut-python==1.0.9) (0.15.2)
# Requirement already satisfied: six in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from zss->donut-python==1.0.9) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python==1.0.9) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python==1.0.9) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python==1.0.9) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python==1.0.9) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python==1.0.9) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from aiohttp->datasets[vision]->donut-python==1.0.9) (1.15.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python==1.0.9) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python==1.0.9) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python==1.0.9) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests->transformers>=4.11.3->donut-python==1.0.9) (2024.7.4)
# Requirement already satisfied: absl-py>=0.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.58.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (3.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (0.38.4)
# Requirement already satisfied: sympy in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.11.1)
# Requirement already satisfied: networkx in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python==1.0.9) (3.1)
# Requirement already satisfied: jinja2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python==1.0.9) (3.1.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from torchmetrics>=0.4.1->pytorch-lightning>=1.6.4->donut-python==1.0.9) (0.11.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pandas->datasets[vision]->donut-python==1.0.9) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pandas->datasets[vision]->donut-python==1.0.9) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pandas->datasets[vision]->donut-python==1.0.9) (2023.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from ruamel.yaml->sconf>=0.2.3->donut-python==1.0.9) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (2.1.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets[vision]->donut-python==1.0.9) (0.2.0)
# Requirement already satisfied: mpmath>=0.19 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from sympy->torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python==1.0.9) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/judy/miniconda3/envs/judy/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python==1.0.9) (3.2.2)
# Building wheels for collected packages: donut-python
#   Building wheel for donut-python (setup.py) ... done
#   Created wheel for donut-python: filename=donut_python-1.0.9-py3-none-any.whl size=21776 sha256=1a2fca764f9cff856bfb384f734adb3412bf744ca56d40d585f599880405a46a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2kd4nh6m/wheels/63/f1/00/e286695f854c7af579d9546be9d1365e105f017c02d9199654
# Successfully built donut-python
# DEPRECATION: pytorch-lightning 1.6.4 has a non-standard dependency specifier torch>=1.8.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: donut-python
#   Attempting uninstall: donut-python
#     Found existing installation: donut-python 1.0.9
#     Uninstalling donut-python-1.0.9:
#       Successfully uninstalled donut-python-1.0.9
# Successfully installed donut-python-1.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cat dataset_name/test/metadata.jsonl
# Out:
# cat: dataset_name/test/metadata.jsonl: No such file or directory
